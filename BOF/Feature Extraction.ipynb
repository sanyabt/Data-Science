# %%
import pandas as pd

# %%
train_data=pd.read_csv('/Users/Seema/Desktop/ML Workshop/BOF/labeledTrainData.tsv', sep='\t')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#use seaborn for plotting defaults
import seaborn as sns
sns.set()

# %%
train_data['review_length']=train_data.review.apply(len)
p=plt.hist(train_data.review_length.values)

# %%
p=plt.hist([train_data[train_data.sentiment==0].review_length.values, train_data[train_data.sentiment==1].review_length.values], label=['negative', 'positive'], color=['RED', 'BLUE'])
plt.legend()

# %%
bp=plt.boxplot([train_data[train_data.sentiment==0].review_length.values, train_data[train_data.sentiment==1].review_length.values], labels=['negative', 'positive'])

# %%
train_data[train_data.sentiment==0].describe()
# Out:
#        sentiment  review length  review_length
# count    12500.0   12500.000000   12500.000000
# mean         0.0    1305.942240    1305.942240
# std          0.0     959.400711     959.400711
# min          0.0      52.000000      52.000000
# 25%          0.0     711.000000     711.000000
# 50%          0.0     978.500000     978.500000
# 75%          0.0    1570.000000    1570.000000
# max          0.0    8999.000000    8999.000000

# %%
train_data[train_data.sentiment==1].describe()
# Out:
#        sentiment  review length  review_length
# count    12500.0   12500.000000   12500.000000
# mean         1.0    1349.965440    1349.965440
# std          0.0    1049.249815    1049.249815
# min          1.0      70.000000      70.000000
# 25%          1.0     695.000000     695.000000
# 50%          1.0     984.000000     984.000000
# 75%          1.0    1654.000000    1654.000000
# max          1.0   13708.000000   13708.000000

# %%
train_data[train_data.review_length==394].review.all()
# Out:
# "Gregory Peck gives a brilliant performance in this film. The last 15 minutes (or thereabouts) are great and Peck is an absolute joy to watch. The same cannot however be said for the rest of the film. It's not awful and I'm sure it was made with good intentions, but the only real reason (if I were to be honest) to see it is Peck. For the rest you are better off just reading the Old Testament."

# %% [raw]
# train_data.review_length

# %%
print(train_data.review_length)
# Out:
# 0        2302
# 1         946
# 2        2455
# 3        2245
# 4        2233
# 5         441
# 6         605
# 7         728
# 8         964
# 9         245
# 10        313
# 11        894
# 12       2296
# 13        760
# 14        615
# 15       1137
# 16       2344
# 17       2505
# 18       1420
# 19        698
# 20       1462
# 21       1640
# 22       1673
# 23        221
# 24        208
# 25        787
# 26       1256
# 27       1383
# 28       3653
# 29        653
#          ...
# 24970    1077
# 24971     633
# 24972    2384
# 24973    1574
# 24974    1658
# 24975     770
# 24976     976
# 24977     906
# 24978    1903
# 24979    1066
# 24980     547
# 24981     359
# 24982    5915
# 24983    1097
# 24984     775
# 24985    1018
# 24986    1017
# 24987    1726
# 24988    2563
# 24989    2254
# 24990    1379
# 24991    1517
# 24992     320
# 24993    2902
# 24994    1880
# 24995     580
# 24996     975
# 24997     641
# 24998    1145
# 24999     942
# ...

# %%
train_data[train_data.review_length==394]
# Out:
#             id  sentiment                                             review  \
# 1612    1994_2          0  This film, originally released at Christmas, 1...
# 4779    6558_2          0  We rented five movies for New Year's Eve weeke...
# 8467   3474_10          1  This film is worth seeing alone for Jared Harr...
# 11102   8375_8          1  <br /><br />Robot jox is a great little film o...
# 18485    301_1          0  This is the worst documentary to come out of C...
# 22308   2767_8          1  Gregory Peck gives a brilliant performance in ...
#
#        review length  review_length
# 1612             394            394
# 4779             394            394
# 8467             394            394
# 11102            394            394
# 18485            394            394
# 22308            394            394
