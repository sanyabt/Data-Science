# %%
import pandas as pd
import numpy as np

# %%
tit_train=pd.read_csv('/Users/Seema/Desktop/ML Workshop/Titanic/train.csv', na_values=['NA'])

# %%
tit_test = pd.read_csv('/Users/Seema/Desktop/ML Workshop/Titanic/test.csv', na_values=['NA'])

# %%
tit_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tit_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tit_train['Survived'].unique()
# Out:
# array([0, 1])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(tit_train.dropna(), hue='Survived')

# %%
tit_train.loc[(tit_train['Age'].isnull())]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
def age_func(row):
    if row['Age']>18:
        return 1
    else:
        return 0
tit_train['adult']=tit_train.apply(age_func, axis=1)

# %%
tit_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  adult
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      1
# ...

# %%
tit_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare       adult
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.645342
# std      0.806057   49.693429    0.478678
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    1.000000
# 75%      0.000000   31.000000    1.000000
# ...

# %%
tit_train.loc[(tit_train['Age'].isnull())].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked  adult
# 5       0      0  330877   8.4583   NaN        Q      0
# 17      0      0  244373  13.0000   NaN        S      0
# 19      0      0    2649   7.2250   NaN        C      0
# 26      0      0    2631   7.2250   NaN        C      0
# 28      0      0  330959   7.8792   NaN        Q      0

# %%
tit_train2=tit_train[['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare', 'adult']]

# %%
tit_train2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age     Fare  adult
# 0    male  22.0   7.2500      1
# 1  female  38.0  71.2833      1
# 2  female  26.0   7.9250      1
# 3  female  35.0  53.1000      1
# 4    male  35.0   8.0500      1

# %%
tit_train2.loc[tit_train2['Age'].isnull()]
# Out:
#      Survived  Pclass                                            Name     Sex  \
# 5           0       3                                Moran, Mr. James    male
# 17          1       2                    Williams, Mr. Charles Eugene    male
# 19          1       3                         Masselmani, Mrs. Fatima  female
# 26          0       3                         Emir, Mr. Farred Chehab    male
# 28          1       3                   O'Dwyer, Miss. Ellen "Nellie"  female
# 29          0       3                             Todoroff, Mr. Lalio    male
# 31          1       1  Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 32          1       3                        Glynn, Miss. Mary Agatha  female
# 36          1       3                                Mamee, Mr. Hanna    male
# 42          0       3                             Kraeff, Mr. Theodor    male
# 45          0       3                        Rogers, Mr. William John    male
# ...

# %%
tit_train2.loc[tit_train2['Age'].isnull() & tit_train2['Survived']==1]
# Out:
#      Survived  Pclass                                               Name  \
# 17          1       2                       Williams, Mr. Charles Eugene
# 19          1       3                            Masselmani, Mrs. Fatima
# 28          1       3                      O'Dwyer, Miss. Ellen "Nellie"
# 31          1       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 32          1       3                           Glynn, Miss. Mary Agatha
# 36          1       3                                   Mamee, Mr. Hanna
# 47          1       3                          O'Driscoll, Miss. Bridget
# 55          1       1                                  Woolner, Mr. Hugh
# 65          1       3                           Moubarek, Master. Gerios
# 82          1       3                     McDermott, Miss. Brigdet Delia
# 107         1       3                             Moss, Mr. Albert Johan
# 109         1       3                                Moran, Miss. Bertha
# ...

# %%
tit_train2.dropna(inplace=True)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tit_train2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age     Fare  adult
# 0    male  22.0   7.2500      1
# 1  female  38.0  71.2833      1
# 2  female  26.0   7.9250      1
# 3  female  35.0  53.1000      1
# 4    male  35.0   8.0500      1

# %%
tit_train2.loc[tit_train2['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, Fare, adult]
# Index: []

# %%
tit_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
all_inputs=tit_train2[['Pclass', 'Sex','Age','Fare']].values

# %%
all_classes=tit_train2['Survived'].values
all_inputs[:5]
# Out:
# array([[3, 'male', 22.0, 7.25],
#        [1, 'female', 38.0, 71.2833],
#        [3, 'female', 26.0, 7.925],
#        [1, 'female', 35.0, 53.1],
#        [3, 'male', 35.0, 8.05]], dtype=object)

# %%
from sklearn.cross_validation import train_test_split

(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.75, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.cross_validation import StratifiedKFold

# %%
def sex_func(row):
    if row['Sex']=="male":
        return 1
    else:
        return 0
tit_train2['sex']=tit_train2.apply(sex_func, axis=1)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tit_train2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age     Fare  adult  sex
# 0    male  22.0   7.2500      1    1
# 1  female  38.0  71.2833      1    0
# 2  female  26.0   7.9250      1    0
# 3  female  35.0  53.1000      1    0
# 4    male  35.0   8.0500      1    1

# %%
all_inputs=tit_train2[['Pclass','Age','Fare','sex']].values

# %%
all_classes=tit_train2['Survived'].values
all_inputs[:5]
# Out:
# array([[  3.    ,  22.    ,   7.25  ,   1.    ],
#        [  1.    ,  38.    ,  71.2833,   0.    ],
#        [  3.    ,  26.    ,   7.925 ,   0.    ],
#        [  1.    ,  35.    ,  53.1   ,   0.    ],
#        [  3.    ,  35.    ,   8.05  ,   1.    ]])

# %%
from sklearn.cross_validation import train_test_split

(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.75, random_state=1)

# %%
from sklearn.cross_validation import cross_val_score

decision_tree_classifier = DecisionTreeClassifier()

# cross_val_score returns a list of the scores, which we can visualize
# to get a reasonable estimate of our classifier's performance
cv_scores = cross_val_score(decision_tree_classifier, all_inputs, all_classes, cv=10)
sb.distplot(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))

# %%
from sklearn.grid_search import GridSearchCV
decision_tree_classifier = DecisionTreeClassifier()

parameter_grid = {'criterion': ['gini', 'entropy'],
                  'splitter': ['best', 'random'],
                  'max_depth': [1, 2, 3, 4, 5],
                  'max_features': [1, 2, 3, 4]}

cross_validation = StratifiedKFold(all_classes, n_folds=10)

grid_search = GridSearchCV(decision_tree_classifier,
                           param_grid=parameter_grid,
                           cv=cross_validation)

grid_search.fit(all_inputs, all_classes)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# Best score: 0.8081232493
# Best parameters: {'max_features': 3, 'splitter': 'best', 'criterion': 'gini', 'max_depth': 4}

# %%
decision_tree_classifier = grid_search.best_estimator_
decision_tree_classifier
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=3, max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
decision_tree_classifier.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-49839026e0de> in <module>()
# ----> 1 decision_tree_classifier.predict()
#
# TypeError: predict() takes at least 2 arguments (1 given)

# %%
tit_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
tit_test2=tit_test[['Pclass','Sex','Age','Fare']]

# %%
tit_test2['sex']=tit_test2.apply(sex_func, axis=1)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tit_test2.head()
# Out:
#    Pclass     Sex   Age     Fare  sex
# 0       3    male  34.5   7.8292    1
# 1       3  female  47.0   7.0000    0
# 2       2    male  62.0   9.6875    1
# 3       3    male  27.0   8.6625    1
# 4       3  female  22.0  12.2875    0

# %%
tit_train2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age     Fare  adult  sex
# 0    male  22.0   7.2500      1    1
# 1  female  38.0  71.2833      1    0
# 2  female  26.0   7.9250      1    0
# 3  female  35.0  53.1000      1    0
# 4    male  35.0   8.0500      1    1

# %%
all_inputs
# Out:
# array([[  3.    ,  22.    ,   7.25  ,   1.    ],
#        [  1.    ,  38.    ,  71.2833,   0.    ],
#        [  3.    ,  26.    ,   7.925 ,   0.    ],
#        ...,
#        [  1.    ,  19.    ,  30.    ,   0.    ],
#        [  1.    ,  26.    ,  30.    ,   1.    ],
#        [  3.    ,  32.    ,   7.75  ,   1.    ]])

# %%
new_inputs=tit_test2[['Pclass','Age','Fare','sex']].values

# %%
new_inputs
# Out:
# array([[  3.    ,  34.5   ,   7.8292,   1.    ],
#        [  3.    ,  47.    ,   7.    ,   0.    ],
#        [  2.    ,  62.    ,   9.6875,   1.    ],
#        ...,
#        [  3.    ,  38.5   ,   7.25  ,   1.    ],
#        [  3.    ,      nan,   8.05  ,   1.    ],
#        [  3.    ,      nan,  22.3583,   1.    ]])

# %%
result=decision_tree_classifier.predict(new_inputs)

# %%
tit_test2.dropna(inplace=True)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tit_test2.describe()
# Out:
#            Pclass         Age        Fare         sex
# count  331.000000  331.000000  331.000000  331.000000
# mean     2.141994   30.181269   40.982087    0.616314
# std      0.846251   14.104573   61.228558    0.487019
# min      1.000000    0.170000    0.000000    0.000000
# 25%      1.000000   21.000000    8.050000    0.000000
# 50%      2.000000   27.000000   16.000000    1.000000
# 75%      3.000000   39.000000   40.633350    1.000000
# max      3.000000   76.000000  512.329200    1.000000

# %%
new_inputs=tit_test2[['Pclass','Age','Fare','sex']].values

# %%
new_inputs
# Out:
# array([[   3.    ,   34.5   ,    7.8292,    1.    ],
#        [   3.    ,   47.    ,    7.    ,    0.    ],
#        [   2.    ,   62.    ,    9.6875,    1.    ],
#        ...,
#        [   3.    ,   28.    ,    7.775 ,    0.    ],
#        [   1.    ,   39.    ,  108.9   ,    0.    ],
#        [   3.    ,   38.5   ,    7.25  ,    1.    ]])

# %%
tit_test2.insert(loc=0, column='survive', value=result)

# %%
tit_test2.head()
# Out:
#    survive  Pclass     Sex   Age     Fare  sex
# 0        0       3    male  34.5   7.8292    1
# 1        1       3  female  47.0   7.0000    0
# 2        0       2    male  62.0   9.6875    1
# 3        0       3    male  27.0   8.6625    1
# 4        1       3  female  22.0  12.2875    0

# %%
tit_test2
# Out:
#      survive  Pclass     Sex   Age      Fare  sex
# 0          0       3    male  34.5    7.8292    1
# 1          1       3  female  47.0    7.0000    0
# 2          0       2    male  62.0    9.6875    1
# 3          0       3    male  27.0    8.6625    1
# 4          1       3  female  22.0   12.2875    0
# 5          0       3    male  14.0    9.2250    1
# 6          1       3  female  30.0    7.6292    0
# 7          0       2    male  26.0   29.0000    1
# 8          1       3  female  18.0    7.2292    0
# 9          0       3    male  21.0   24.1500    1
# 11         0       1    male  46.0   26.0000    1
# 12         1       1  female  23.0   82.2667    0
# 13         0       2    male  63.0   26.0000    1
# 14         1       1  female  47.0   61.1750    0
# 15         1       2  female  24.0   27.7208    0
# 16         0       2    male  35.0   12.3500    1
# 17         0       3    male  21.0    7.2250    1
# 18         1       3  female  27.0    7.9250    0
# ...

# %%
tit_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
tit_test.loc[tit_test['Age'].isnull()]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# 39           931       3                                      Hee, Mr. Ling
# 41           933       1                        Franklin, Mr. Thomas Parham
# 47           939       3                           Shaughnessy, Mr. Patrick
# 54           946       2                  Mangiavacchi, Mr. Serafino Emilio
# 58           950       3                          Davison, Mr. Thomas Henry
# 65           957       2  Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...
# ...
